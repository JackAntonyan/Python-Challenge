# %%
# Input Libraries
import csv
import os

# Path of the file
path = "03-Python_Homework_Instructions_PyPoll_Resources_election_data.csv"

# Join the path
csvpath = os.path.join(path)

# Empty Lists
num_votes = []
percent_votes = []
candidates = []
total_votes = 0

# Open and read the csv file
with open(path, newline = "") as csv_file:
    csvreader = csv.reader(csv_file, delimiter = ",")
    

    # Skip the header to iterate through rows
    header = next(csvreader)

    # Iterate through rows and append the total votes to its corresponding list
    for row in csvreader:
        num_votes.append(row[0])
        
        total_votes +=1
        
        if row[2] not in candidates:
            candidates.append(row[2])
            index = candidates.index(row[2])
            num_votes.append(1)
        else:
            index = candidates.index(row[2])
            num_votes[index] += 1
    
    for votes in num_votes:
        percentage = round(votes/total_votes*100,2)
        percent_votes.append(percentage)
    
    for i in range(len(candidates)):


    # Find the winning candidate
        winner = max(num_votes)
        index = num_votes.index(winner)
        winning_candidate = candidates[index]
        
# The total number of votes cast        
print(f"Total votes: {len_votes}")

# A complete list of candidates who received votes
    for i in range(len(candidates)):
        candidates = candidates[i]

# The percentage of votes each candidate won
        percent_votes = percent_votes[i]
    
    
# The total number of votes each candidate won
        num_votes = num_votes[i]
   
        

print(f"{candidates}: {str(percent_votes)} ({str(num_votes)})")

# The winner of the election based on popular vote.

print(f"Winner: {winning_candidate}")

# As an example, your analysis should look similar to the one below:
# Election Results
# -------------------------
# Total Votes: 3521001
# -------------------------
# Khan: 63.000% (2218231)
# Correy: 20.000% (704200)
# Li: 14.000% (492940)
# O'Tooley: 3.000% (105630)
# -------------------------
# Winner: Khan
# -------------------------
# Out:
#   File "<ipython-input-46-99b68cf1194f>", line 55
#     for i in range(len(candidates)):
#     ^
# IndentationError: unexpected indent
